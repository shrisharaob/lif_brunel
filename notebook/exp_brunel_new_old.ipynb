# %% [markdown]
# # Brunel LIF network

# %%
"jupytext_formats: ipynb,py"
import sys 
sys.path.append("../")
import simulate

# %% [markdown]
# # AI g=5, v_ext/v_thresh = 2.0

# %%
simulate.runsim(v_ext = 0.002, g_brunel=5., t_stop=2000., discard_time=100.)
# Out:
# loading spikes
# done
# CV = 0.8967840905460649

# %%
simulate.runsim(v_ext = 0.02, g_brunel=8., t_stop=2001., discard_time=100.)
# Out:
# loading spikes
# done
# CV = 0.07046135196396201

# %%
simulate.runsim(v_ext = 0.04, g_brunel=6., t_stop=100., discard_time=50.)
# Out:
# loading spikes
# done
# CV = 0.02786852966935752

# %%
simulate.runsim(v_ext = 0.012, g_brunel=4., t_stop=500., discard_time=50.)
# Out:
# loading spikes
# done
# CV = 0.025085643419258105

# %%
simulate.runsim(v_ext = 0.012, g_brunel=8., t_stop=500., discard_time=50.)
# Out:
# loading spikes
# done
# CV = 0.10640234659948575

# %% [markdown]
# # SR g=1, v_ext/v_thresh = 1, D = 1.5ms

# %%
simulate.runsim(v_ext = 0.02, g_brunel=1.0, t_stop=1000.)
# Out:
# loading spikes
# done
# CV = 0.03879350675565185
# r_E = 17.6866Hz
# r_I = 17.6902Hz

# %% [markdown]
# # SR g=1, v_ext/v_thresh = 2

# %%
simulate.runsim(v_ext = 1.0/40, g_brunel=1.0, t_stop=10.)

# %% [markdown]
# # AI g=4, v_ext/v_thresh = 1

# %%
simulate.runsim(v_ext = 1.0/80, g_brunel=4.0, t_stop=1000.)
# Out:
# loading spikes
# done
# CV = 0.15416139507403073
# r_E = 11.2250Hz
# r_I = 11.2275Hz

# %% [markdown]
# # SI slow osc. g=4.5, v_ext/v_thresh = 0.90

# %%
simulate.runsim(v_ext = 0.01 * 1., g_brunel=4.5, t_stop=200.)
# Out:
# loading spikes
# done
# ../simulate.py:171: RuntimeWarning: Mean of empty slice
#   coeff_of_var = np.nanmean(cv(st, n_neurons))
# CV = nan
# r_E = 7.6118Hz
# r_I = 7.6922Hz

# %% [markdown]
# # SI fast osc. g=6, v_ext/v_thresh = .75

# %%
simulate.runsim(v_ext = 3.5/80, g_brunel=7.0, t_stop=200.)
# Out:
# loading spikes
# done

# %%
st = np.loadtxt('./data/spikes.txt')
st = st[st[:, 0] > .990, :] # plot only the last 10ms
simulate.pu.plot_raster(st)
