# %% [markdown]
# # Brunel LIF network

# %%
"jupytext_formats: ipynb,py"
import sys 
sys.path.append("../")
import simulate

# %% [markdown]
# # AI g=5, v_ext/v_thresh = 2.0

# %%
simulate.runsim(v_ext = 0.002, g_brunel=5., t_stop=1000., discard_time=100.)
# Out:
# loading spikes
# done
# CV = 0.4263085490766544

# %%
simulate.runsim(v_ext = 0.002, g_brunel=5., t_stop=100., discard_time=100.)
# Out:
# loading spikes
# done
# CV = 0.28805153131890926

# %% [markdown]
# # SR g=1, v_ext/v_thresh = 1, D = 1.5ms

# %%
simulate.runsim(v_ext = 0.01, g_brunel=1.0, t_stop=100.)
# Out:
# loading spikes
# done
# CV = 1.2526804719729774e-15

# %% [markdown]
# # SI slow osc. g=4.5, v_ext/v_thresh = 0.90

# %%
simulate.runsim(v_ext = 0.009, g_brunel=4.5, t_stop=100.)
# Out:
# loading spikes
# done
# CV = 0.1544231698871466

# %% [markdown]
# #### SI fast osc. g=6, v_ext/v_thresh =4.

# %%
simulate.runsim(v_ext = .04, g_brunel=6.0, t_stop=20.)
# Out:
# loading spikes
# done
# CV = 0.008851028619379057

# %%
simulate.runsim(v_ext = 0.002, g_brunel=5., t_stop=100., discard_time=100.)
# Out:
# loading spikes
# done
# CV = 0.2789313491844589

# %%
simulate.runsim(v_ext = 0.02, g_brunel=5., t_stop=100., discard_time=100.)
# Out:
# loading spikes
# done
# CV = 0.04239093715170798

# %%
simulate.runsim(dt=1e-1, v_ext = .002, J=0.1, g_brunel=5., t_stop=1000., discard_time=100.)
# Out:
# loading spikes
# done
# r_E = 39.5582Hz
# r_I = 39.1345Hz
# CV = 0.41709442151983434

# %%
simulate.runsim(v_ext = .0009, J=0.1, g_brunel=4.5, t_stop=10000., discard_time=100.)
# Out:
# loading spikes
# done
# r_E = 7.0944Hz
# r_I = 6.9978Hz
# CV = 0.7038928083739057

# %%
st = np.loadtxt('data/spikes.txt')
simulate.plot_random_slection(st, 0.1, 9000, 10000.)
