# %%
"jupytext_formats: ipynb,py"
import sys 
sys.path.append("../")
import simulate

# %% [markdown]
# ## AI regime? (v_ext/v_thresh = )

# %%
simulate.runsim(v_ext=1.7e-4, Jee=1e-1, t_stop=1000., g_brunel=5.0)
# Out:
# loading spikes
# done
# r_E = 911.70Hz
# r_I = 911.73Hz

# %%
simulate.runsim(v_ext=1.2e-4, Jee=1e-1, t_stop=1000.)
# Out:
# loading spikes
# done
# r_E = 0.01Hz
# r_I = 0.01Hz

# %%
.2/800
# Out:
# 0.00025

# %%
simulate.runsim(v_ext=1.2e-4, Jee=1e-1, t_stop=1000., g_brunel=1.0)
# Out:
# loading spikes
# done
# r_E = 0.01Hz
# r_I = 0.01Hz

# %%
simulate.runsim(v_ext=1.2e-4, Jee=1e-1, t_stop=1000., g_brunel=4.)
# Out:
# loading spikes
# done
# r_E = 0.01Hz
# r_I = 0.01Hz

# %%
simulate.runsim(v_ext=1.5e-4, Jee=1e-1, t_stop=1000., g_brunel=3.5)
# Out:
# loading spikes
# done
# r_E = 0.12Hz
# r_I = 0.11Hz

# %% [markdown]
# ## AI regime? (Brunel params: v_ext/v_thresh = 2., g = 5)
# ### Fast oscillations instead

# %%
simulate.runsim(v_ext=0.025, Jee=1e-1, t_stop=1000., g_brunel=5.0)
# Out:
# loading spikes
# done
# r_E = 1643.92Hz
# r_I = 1643.98Hz

# %%
simulate.runsim(v_ext=0.1e-3, Jee=1e-1, t_stop=5000., g_brunel=4.1)
# Out:
# loading spikes
# done
# r_E = 0.0019Hz
# r_I = 0.0022Hz

# %%
simulate.runsim(v_ext=0.02, Jee=1e-1, t_stop=100., g_brunel=1.)
# Out:
# loading spikes
# done
# r_E = 255.6650Hz
# r_I = 255.7537Hz

# %%
simulate.runsim(v_ext=0.02, Jee=1e-1, t_stop=100., g_brunel=.1)
# Out:
# loading spikes
# done
# r_E = 255.6650Hz
# r_I = 255.7537Hz

# %%
simulate.runsim(v_ext=0.02, Jee=1e-1, t_stop=100., g_brunel=4.)
# Out:
# loading spikes
# done
# r_E = 255.6650Hz
# r_I = 255.7537Hz

# %%
simulate.runsim(v_ext=0.2, Jee=1e-1, t_stop=100., g_brunel=5.)
# Out:
# loading spikes
# done
# r_E = 529.3768Hz
# r_I = 529.3153Hz

# %%
simulate.runsim(v_ext=0.2, Jee=1e-1, t_stop=100., g_brunel=10.)
# Out:
# loading spikes
# done
# r_E = 529.3768Hz
# r_I = 529.3153Hz

# %%
simulate.runsim(v_ext=0.02, Jee=1e-1, t_stop=100., g_brunel=10.)
# Out:
# loading spikes
# done
# r_E = 255.6650Hz
# r_I = 255.7537Hz

# %%
simulate.runsim(v_ext=20., Jee=0.1e-3, t_stop=1000., g_brunel=5.0)
# Out:
# loading spikes
# done
# r_E = 80.9877Hz
# r_I = 80.9877Hz

# %%
simulate.runsim(v_ext=2e-3, Jee=0.1, t_stop=100., g_brunel=5.0)
# Out:
# loading spikes
# done
# r_E = 521.8701Hz
# r_I = 523.1520Hz

# %%
simulate.runsim(v_ext=2e-3, Jee=0.1, t_stop=100., g_brunel=1.0)
# Out:
# loading spikes
# done
# r_E = 550.2206Hz
# r_I = 551.7304Hz
